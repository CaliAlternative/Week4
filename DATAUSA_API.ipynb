# %%
import requests
import json
from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize

# %%
url = "http://api.datausa.io/api/?show=geo&sumlevel=state&required=avg_wage"
API_Response = requests.get(url)
if(API_Response.status_code == 200):
    print("The request was good")
elif(API_Response.status_code == 404):
    print("Naw, it aint workin")
# Out:
# Naw, it aint workin

# %%
newurl = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
API_Response1 = requests.get(newurl)
if(API_Response1.status_code == 200):
    print("The request was good\n")
    print()
    pprint(API_Response1.json())
elif(API_Response1.status_code == 404):
    print("Naw, it aint workin")
# Out:
# The request was good
#
#
# {'data': [{'ID Nation': '01000US',
#            'ID Year': 2019,
#            'Nation': 'United States',
#            'Population': 328239523,
#            'Slug Nation': 'united-states',
#            'Year': '2019'},
#           {'ID Nation': '01000US',
#            'ID Year': 2018,
#            'Nation': 'United States',
#            'Population': 327167439,
#            'Slug Nation': 'united-states',
#            'Year': '2018'},
#           {'ID Nation': '01000US',
#            'ID Year': 2017,
#            'Nation': 'United States',
#            'Population': 325719178,
#            'Slug Nation': 'united-states',
#            'Year': '2017'},
#           {'ID Nation': '01000US',
#            'ID Year': 2016,
#            'Nation': 'United States',
#            'Population': 323127515,
#            'Slug Nation': 'united-states',
#            'Year': '2016'},
#           {'ID Nation': '01000US',
#            'ID Year': 2015,
# ...

# %%
def ApiConnection(Inputurl: str):
    WebsiteResponse = requests.get(Inputurl)
    if(WebsiteResponse.status_code == 200):
        print("The request was good\n")
        print()
        
        
        
        
    elif(WebsiteResponse.status_code == 404):
        print()
        print("Naw, it aint workin")
    return  WebsiteResponse

GetWebsiteURL = input("Please Enter URL")
ApiConnection(GetWebsiteURL)
# Out:
# Please Enter URLhttps://datausa.io/api/data?drilldowns=Nation&measures=Population
# The request was good
# <Response [200]>

# %%
def ApiConnection(Inputurl: str):
    WebsiteResponse = requests.get(Inputurl)
    if(WebsiteResponse.status_code == 200):
        print("The request was good\n")
        print()
        
        
        data = WebsiteResponse.json()
        print("-------------------------------------------------------------------------------")
        pprint(data.values())
        print("-------------------------------------------------------------------------------")
        print()
        print("*******************************************************************************")
        pprint(data.keys())
        print("********************************************************************************")
        pprint(WebsiteResponse.json())
        
        
    elif(WebsiteResponse.status_code == 404):
        print()
        print("Naw, it aint workin")
    return  data

GetWebsiteURL = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
ApiConnection(GetWebsiteURL)
# Out:
# The request was good
#
#
# -------------------------------------------------------------------------------
# ...

# %%
def ApiConnection(Inputurl: str):
    if(WebsiteResponse.status_code == 200):
        print("The request was good\n")
        print()
        
        
        
        
        
    elif(WebsiteResponse.status_code == 404):
        print()
        print("Naw, it aint workin")
    return  data

GetWebsiteURL = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
ApiConnection(GetWebsiteURL)

# %%
GetWebsiteURL = "https://datausa.io/api/data?drilldowns=Nation&measures=Population"
WebsiteResponse = requests.get(GetWebsiteURL)
x = WebsiteResponse.json()
pprint(x)
df = pd.read_json(GetWebsiteURL)
# Out:
# {'data': [{'ID Nation': '01000US',
#            'ID Year': 2019,
#            'Nation': 'United States',
#            'Population': 328239523,
#            'Slug Nation': 'united-states',
#            'Year': '2019'},
#           {'ID Nation': '01000US',
#            'ID Year': 2018,
#            'Nation': 'United States',
#            'Population': 327167439,
#            'Slug Nation': 'united-states',
#            'Year': '2018'},
#           {'ID Nation': '01000US',
#            'ID Year': 2017,
#            'Nation': 'United States',
#            'Population': 325719178,
#            'Slug Nation': 'united-states',
#            'Year': '2017'},
#           {'ID Nation': '01000US',
#            'ID Year': 2016,
#            'Nation': 'United States',
#            'Population': 323127515,
#            'Slug Nation': 'united-states',
#            'Year': '2016'},
#           {'ID Nation': '01000US',
#            'ID Year': 2015,
#            'Nation': 'United States',
# ...

# %%
url = "https://api.exchangerate-api.com/v4/latest/USD"
df = pd.read_json(url)
print(df)
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...
